# %% [markdown]
# # Reading dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import mode
from scipy.stats import chi2_contingency

# %%
#read csv
initial_test_data = pd.read_csv("test.csv")
initial_train_data = pd.read_csv("train.csv")
initial_gender_data = pd.read_csv("gender_submission.csv")

# %%
initial_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Finding categories of different columns

# %%
len(initial_train_data['PassengerId'].unique())
# Out:
# 891

# %%
initial_train_data['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
len(initial_train_data['Name'].unique())
# Out:
# 891

# %%
initial_train_data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
len(initial_train_data['Age'].unique())
# Out:
# 89

# %%
initial_train_data['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
initial_train_data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
len(initial_train_data['Ticket'].unique())
# Out:
# 681

# %%
initial_train_data['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
#         79.2   ,   6.75  ,  11.5   ,  36.75  ,   7.7958,  12.525 ,
#         66.6   ,   7.3125,  61.3792,   7.7333,  69.55  ,  16.1   ,
#         15.75  ,  20.525 ,  55.    ,  25.925 ,  33.5   ,  30.6958,
#         25.4667,  28.7125,   0.    ,  15.05  ,  39.    ,  22.025 ,
#         50.    ,   8.4042,   6.4958,  10.4625,  18.7875,  31.    ,
#        113.275 ,  27.    ,  76.2917,  90.    ,   9.35  ,  13.5   ,
#          7.55  ,  26.25  ,  12.275 ,   7.125 ,  52.5542,  20.2125,
#         86.5   , 512.3292,  79.65  , 153.4625, 135.6333,  19.5   ,
#         29.7   ,  77.9583,  20.25  ,  78.85  ,  91.0792,  12.875 ,
#          8.85  , 151.55  ,  30.5   ,  23.25  ,  12.35  , 110.8833,
#        108.9   ,  24.    ,  56.9292,  83.1583, 262.375 ,  14.    ,
#        164.8667, 134.5   ,   6.2375,  57.9792,  28.5   , 133.65  ,
#         15.9   ,   9.225 ,  35.    ,  75.25  ,  69.3   ,  55.4417,
#        211.5   ,   4.0125, 227.525 ,  15.7417,   7.7292,  12.    ,
#        120.    ,  12.65  ,  18.75  ,   6.8583,  32.5   ,   7.875 ,
#         14.4   ,  55.9   ,   8.1125,  81.8583,  19.2583,  19.9667,
#         89.1042,  38.5   ,   7.725 ,  13.7917,   9.8375,   7.0458,
#          7.5208,  12.2875,   9.5875,  49.5042,  78.2667,  15.1   ,
#          7.6292,  22.525 ,  26.2875,  59.4   ,   7.4958,  34.0208,
#         93.5   , 221.7792, 106.425 ,  49.5   ,  71.    ,  13.8625,
#          7.8292,  39.6   ,  17.4   ,  51.4792,  26.3875,  30.    ,
#         40.125 ,   8.7125,  15.    ,  33.    ,  42.4   ,  15.55  ,
#         65.    ,  32.3208,   7.0542,   8.4333,  25.5875,   9.8417,
#          8.1375,  10.1708, 211.3375,  57.    ,  13.4167,   7.7417,
#          9.4833,   7.7375,   8.3625,  23.45  ,  25.9292,   8.6833,
#          8.5167,   7.8875,  37.0042,   6.45  ,   6.95  ,   8.3   ,
#          6.4375,  39.4   ,  14.1083,  13.8583,  50.4958,   5.    ,
#          9.8458,  10.5167])

# %%
len(initial_train_data['Cabin'].unique())
# Out:
# 148

# %%
initial_train_data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# # Feature engineering (Along with hyper pruning)

# %% [markdown]
# ## After initial analysis of the dataset, we see that follwoing fields are unique and does not contribute to survival of the passenger:
# 1> Name
# 2> PassengerId
# So we will drop these fields

# %%
initial_train_data.drop(columns=['Name','PassengerId'], inplace=True)

# %% [markdown]
# ## Removing NaN from dataset

# %% [markdown]
# Columns having NaN will be replaced with proper values. The dataset should not have any cell as NaN

# %% [markdown]
# ## Filling the age value not available with median of all ages (A part of hyper pruning which was figured out with experimentation with data)

# %%
median_age = initial_train_data['Age'].median()
median_age
# Out:
# 28.0

# %%
initial_train_data.loc[initial_train_data['Age'].isna(), 'Age'] = round(median_age)

# %%
initial_train_data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# ## One Hot encoding for Embarked

# %%
initial_train_data['Embarked'].isna().sum()
# Out:
# 2

# %%
initial_train_data = pd.get_dummies(initial_train_data, columns=['Embarked'], drop_first=False)
initial_train_data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0     NaN       False       False        True
# 1     C85        True       False       False
# 2     NaN       False       False        True
# 3    C123       False       False        True
# 4     NaN       False       False        True
# ..    ...         ...         ...         ...
# 886   NaN       False       False        True
# 887   B42       False       False        True
# 888   NaN       False       False        True
# 889  C148        True       False       False
# 890   NaN       False        True       False
#
# [891 rows x 12 columns]

# %%
mapping_boolean = {False: 0, True: 1}
initial_train_data['Embarked_Q'] = initial_train_data['Embarked_Q'].map(mapping_boolean)
initial_train_data['Embarked_S'] = initial_train_data['Embarked_S'].map(mapping_boolean)
initial_train_data['Embarked_C'] = initial_train_data['Embarked_C'].map(mapping_boolean)
initial_train_data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0     NaN           0           0           1
# 1     C85           1           0           0
# 2     NaN           0           0           1
# 3    C123           0           0           1
# 4     NaN           0           0           1
# ..    ...         ...         ...         ...
# 886   NaN           0           0           1
# 887   B42           0           0           1
# 888   NaN           0           0           1
# 889  C148           1           0           0
# 890   NaN           0           1           0
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Labelling Sex

# %%
mapping = {'male': 0, 'female': 1}
initial_train_data['Sex'] = initial_train_data['Sex'].map(mapping)
initial_train_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    0  22.0      1      0         A/5 21171   7.2500
# 1           1       1    1  38.0      1      0          PC 17599  71.2833
# 2           1       3    1  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1    1  35.0      1      0            113803  53.1000
# 4           0       3    0  35.0      0      0            373450   8.0500
# ..        ...     ...  ...   ...    ...    ...               ...      ...
# 886         0       2    0  27.0      0      0            211536  13.0000
# 887         1       1    1  19.0      0      0            112053  30.0000
# 888         0       3    1  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    0  26.0      0      0            111369  30.0000
# 890         0       3    0  32.0      0      0            370376   7.7500
#
#     Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0     NaN           0           0           1
# 1     C85           1           0           0
# 2     NaN           0           0           1
# 3    C123           0           0           1
# 4     NaN           0           0           1
# ..    ...         ...         ...         ...
# 886   NaN           0           0           1
# 887   B42           0           0           1
# 888   NaN           0           0           1
# 889  C148           1           0           0
# 890   NaN           0           1           0
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Factorization Heat map with the fields

# %%
initial_train_data_encoded = initial_train_data.apply(lambda x: pd.factorize(x)[0])
sns.heatmap(initial_train_data_encoded.corr(), annot=True, cmap='coolwarm', fmt='.1f')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ## From the correlation matrix, we see that the following fields are not correlated with 'Survived'.
# 1> Age,
# 2> Ticket
# 3> Embarked_Q

# %% [markdown]
# ## We will drop 'Ticket' here since it is not categorical and check with correlation heatmap for 'Age' and 'Embarked_Q'

# %%
initial_train_data.drop(columns=['Ticket'], inplace=True)

# %%
initial_train_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  Embarked_C  \
# 0           0       3    0  22.0      1      0   7.2500   NaN           0
# 1           1       1    1  38.0      1      0  71.2833   C85           1
# 2           1       3    1  26.0      0      0   7.9250   NaN           0
# 3           1       1    1  35.0      1      0  53.1000  C123           0
# 4           0       3    0  35.0      0      0   8.0500   NaN           0
# ..        ...     ...  ...   ...    ...    ...      ...   ...         ...
# 886         0       2    0  27.0      0      0  13.0000   NaN           0
# 887         1       1    1  19.0      0      0  30.0000   B42           0
# 888         0       3    1  28.0      1      2  23.4500   NaN           0
# 889         1       1    0  26.0      0      0  30.0000  C148           1
# 890         0       3    0  32.0      0      0   7.7500   NaN           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 11 columns]

# %% [markdown]
# ## Performing Chi-square test for 'Cabin'

# %%
# Create a contingency table
contingency_table = pd.crosstab(initial_train_data['Survived'], initial_train_data['Cabin'])
# Perform the chi-square test for independence
chi2, p, _, _ = chi2_contingency(contingency_table)
print("Chi-value: ",chi2)
print(" P-value: ", p)
# Out:
# Chi-value:  161.25
#  P-value:  0.18357354976388165

# %% [markdown]
# ## We see a relatively higher Chi2 value but the P-value is less. Also, 'Cabin' is not a categorical column. So, we will drop this column

# %%
initial_train_data.drop(columns=['Cabin'], inplace=True)

# %%
initial_train_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  \
# 0           0       3    0  22.0      1      0   7.2500           0
# 1           1       1    1  38.0      1      0  71.2833           1
# 2           1       3    1  26.0      0      0   7.9250           0
# 3           1       1    1  35.0      1      0  53.1000           0
# 4           0       3    0  35.0      0      0   8.0500           0
# ..        ...     ...  ...   ...    ...    ...      ...         ...
# 886         0       2    0  27.0      0      0  13.0000           0
# 887         1       1    1  19.0      0      0  30.0000           0
# 888         0       3    1  28.0      1      2  23.4500           0
# 889         1       1    0  26.0      0      0  30.0000           1
# 890         0       3    0  32.0      0      0   7.7500           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 10 columns]

# %%
initial_gender_data
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
y = initial_train_data['Survived']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# ## Correlation Heatmap

# %%
sns.heatmap(initial_train_data.corr(), annot=True, fmt=".1f")
# Out:
# <Axes: >

# %% [markdown]
# ## Correlation heat map shows that the following columns are not correlated to 'Survived'. Drop those columns:
# 1> SibSp,
# 2> Embarked_Q
# ## Following columns are have very less correlation to 'Survived'. Drop those columns as well:
# 1> Age
# 2> Parch

# %%
initial_train_data.drop(columns=['SibSp','Embarked_Q'], inplace=True)

# %%
initial_train_data.drop(columns=['Age','Parch'], inplace=True)

# %% [markdown]
# ## Remove y-axis/target column from dataset

# %%
initial_train_data.drop(columns=['Survived'], inplace=True)
initial_train_data
# Out:
#      Pclass  Sex     Fare  Embarked_C  Embarked_S
# 0         3    0   7.2500           0           1
# 1         1    1  71.2833           1           0
# 2         3    1   7.9250           0           1
# 3         1    1  53.1000           0           1
# 4         3    0   8.0500           0           1
# ..      ...  ...      ...         ...         ...
# 886       2    0  13.0000           0           1
# 887       1    1  30.0000           0           1
# 888       3    1  23.4500           0           1
# 889       1    0  30.0000           1           0
# 890       3    0   7.7500           0           0
#
# [891 rows x 5 columns]

# %%
X = initial_train_data
X.shape
# Out:
# (891, 5)

# %% [markdown]
# # Splitting test train dataset to measure accuracy score on a part of the test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
print ("Shape of training dataset: ",X_train.shape)
print ("Shape of testing dataset: ",X_test.shape)
# Out:
# Shape of training dataset:  (801, 5)
# Shape of testing dataset:  (90, 5)

# %% [markdown]
# # Decision Tree Classifier
# Keeping the Criteria as Entropy

# %% [markdown]
# Random state is kept as 65(experimental)

# %%
clf = DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
#Prediction and accuracy on test split of data of the initial_train_data dataframe

y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print ("Accuracy is:", accuracy*100,"%")
# Out:
# Accuracy is: 86.66666666666667 %

# %%
plt.figure(figsize=(40,30))  # Adjust the figure size as needed
plot_tree(clf, filled=True)
plt.show()

# %% [markdown]
# # Predict values in testing dataset for Decision Tree

# %%
# Required columns in test data to predict the value. 
# The columns the dataframe given for prediction should eb same and in order to the columns in test dataframe

# required_columns = ['Pclass','Sex','Fare','Embarked']
required_columns = ['Pclass','Sex','Fare','Embarked']
predicting_dataframe = initial_test_data[required_columns].copy()

# %%
## One Hot encoding for Embarked

predicting_dataframe['Embarked'].isna().sum()

predicting_dataframe = pd.get_dummies(predicting_dataframe, columns=['Embarked'], drop_first=False)
predicting_dataframe.drop(columns=['Embarked_Q'], inplace=True)
predicting_dataframe
# Out:
#      Pclass     Sex      Fare  Embarked_C  Embarked_S
# 0         3    male    7.8292       False       False
# 1         3  female    7.0000       False        True
# 2         2    male    9.6875       False       False
# 3         3    male    8.6625       False        True
# 4         3  female   12.2875       False        True
# ..      ...     ...       ...         ...         ...
# 413       3    male    8.0500       False        True
# 414       1  female  108.9000        True       False
# 415       3    male    7.2500       False        True
# 416       3    male    8.0500       False        True
# 417       3    male   22.3583        True       False
#
# [418 rows x 5 columns]

# %%
# Mapping the categorical values

mapping_sex = {'male': 0, 'female': 1}
predicting_dataframe['Sex'] = predicting_dataframe['Sex'].map(mapping_sex)
mapping_boolean = {False: 0, True: 1}
predicting_dataframe['Embarked_S'] = predicting_dataframe['Embarked_S'].map(mapping_boolean)
predicting_dataframe['Embarked_C'] = predicting_dataframe['Embarked_C'].map(mapping_boolean)

# %%
predicting_dataframe
# Out:
#      Pclass  Sex      Fare  Embarked_C  Embarked_S
# 0         3    0    7.8292           0           0
# 1         3    1    7.0000           0           1
# 2         2    0    9.6875           0           0
# 3         3    0    8.6625           0           1
# 4         3    1   12.2875           0           1
# ..      ...  ...       ...         ...         ...
# 413       3    0    8.0500           0           1
# 414       1    1  108.9000           1           0
# 415       3    0    7.2500           0           1
# 416       3    0    8.0500           0           1
# 417       3    0   22.3583           1           0
#
# [418 rows x 5 columns]

# %%
predicted_values_decision_tree = clf.predict(predicting_dataframe)

# %%
accuracy = accuracy_score(initial_gender_data['Survived'], predicted_values_decision_tree)
print ("Accuracy is:", accuracy*100,"%")
# Out:
# Accuracy is: 87.32057416267942 %

# %% [markdown]
# # Random forest classifier

# %%
clfr = RandomForestClassifier(n_estimators=100)

# %%
clfr.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Prediction and accuracy on test split of data of the initial_train_data dataframe

y_pred = clfr.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print ("Accuracy is:", accuracy*100,"%")
# Out:
# Accuracy is: 86.66666666666667 %

# %% [markdown]
# # Predict values in testing Dataset for Random Forest Classifier

# %%
# Replacing NaN Fare value as mode
modal_fare = predicting_dataframe['Fare'].mode()
predicting_dataframe.loc[predicting_dataframe['Fare'].isna(), 'Fare'] = round(median_age)

# %%
predicted_values_random_forest_classifier = clfr.predict(predicting_dataframe)

# %%
accuracy = accuracy_score(initial_gender_data['Survived'], predicted_values_random_forest_classifier)
print ("Accuracy is:", accuracy*100,"%")
# Out:
# Accuracy is: 88.51674641148325 %

# %% [markdown]
# # Decision Tree vs Random Forest Classifier
# Comparing accuracy or Decision Tree and Random Forest, we find that Random  is providing more accuracy. So we can select Random Forest Classifier model for this dataset
#
# We also have a problem using random Forest Classifier with this dataset as it has NaN values and NaN is not accepted in random Forest

# %% [markdown]
# # Final dataframe

# %%
initial_test_data['Survived'] = predicted_values_random_forest_classifier

# %%
initial_gender_data
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
initial_test_data[['PassengerId','Survived']]
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
new_order = ['PassengerId','Survived','Pclass','Name','Sex','Age',
             'SibSp','Parch','Ticket','Fare','Cabin','Embarked']

# %%
initial_test_data[new_order]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# https://github.com/Simreeta/Titanic_survival_prediction
